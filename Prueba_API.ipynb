# %% [markdown]
# # Implementacion de API

# %%
import pandas as pd

# Datos prueba
data_test =  pd.read_csv("datos_prueba.csv")

# %%
data_dict = data_test.to_dict(orient='list')
data_test
# Out:
#      CustomerID  NameStyle  Title  FirstName  MiddleName  LastName  Suffix
# 0             1        NaN    NaN        NaN         NaN       NaN     NaN  \
# 1             2        NaN    NaN        NaN         NaN       NaN     NaN
# 2             3        NaN    NaN        NaN         NaN       NaN     NaN
# 3             4        NaN    NaN        NaN         NaN       NaN     NaN
# 4             5        NaN    NaN        NaN         NaN       NaN     NaN
# ..          ...        ...    ...        ...         ...       ...     ...
# 995         996        NaN    NaN        NaN         NaN       NaN     NaN
# 996         997        NaN    NaN        NaN         NaN       NaN     NaN
# 997         998        NaN    NaN        NaN         NaN       NaN     NaN
# 998         999        NaN    NaN        NaN         NaN       NaN     NaN
# 999        1000        NaN    NaN        NaN         NaN       NaN     NaN
#
#      CompanyName  SalesPerson  EmailAddress         Phone  PasswordHash
# 0            NaN          NaN           NaN  714-956-6024           NaN  \
# 1            NaN          NaN           NaN  277-343-5647           NaN
# 2            NaN          NaN           NaN  719-726-4924           NaN
# 3            NaN          NaN           NaN  543-885-5846           NaN
# 4            NaN          NaN           NaN  615-554-3020           NaN
# ..           ...          ...           ...           ...           ...
# 995          NaN          NaN           NaN  897-575-6308           NaN
# 996          NaN          NaN           NaN  130-257-9894           NaN
# 997          NaN          NaN           NaN  529-543-5660           NaN
# 998          NaN          NaN           NaN  129-899-3933           NaN
# 999          NaN          NaN           NaN  661-739-8234           NaN
#
#      PasswordSalt  rowguid ModifiedDate
# 0             NaN      NaN   2025-08-06
# 1             NaN      NaN   2024-05-09
# 2             NaN      NaN   2023-02-10
# 3             NaN      NaN   2022-10-05
# 4             NaN      NaN   2024-09-09
# ..            ...      ...          ...
# 995           NaN      NaN   2020-01-16
# 996           NaN      NaN   2022-12-19
# 997           NaN      NaN   2024-05-08
# 998           NaN      NaN   2022-06-15
# 999           NaN      NaN   2022-12-31
#
# [1000 rows x 15 columns]

# %%
import json

# Formateado para la API:
data_json = json.dumps({"data": [data_dict]})

suri = open("uri.json", "r")
scoring_uri = json.load(suri)["URI"]#[0]
suri.close()

# %%
import requests
headers = {"Content-Type": "application/json"}
response = requests.post(scoring_uri, data=data_json, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[18], line 3
#       1 import requests
#       2 headers = {"Content-Type": "application/json"}
# ----> 3 response = requests.post(scoring_uri, data=data_json, headers=headers)
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:697, in Session.send(self, request, **kwargs)
#     694 hooks = request.hooks
#     696 # Get the appropriate adapter to use
# --> 697 adapter = self.get_adapter(url=request.url)
#     699 # Start time (approximately) of the request
#     700 start = preferred_clock()
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:794, in Session.get_adapter(self, url)
#     791         return adapter
#     793 # Nothing matches :-/
# --> 794 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for "['http://12c7573b-6592-4f10-8112-25a182703aff.centralindia.azurecontainer.io/score']"

# %%
headers = {"Content-Type": "application/json"}
import requests

response = requests.post(scoring_uri, data=data_json, headers=headers)

if response.status_code == 200:
  result = json.loads(response.json())
  print(result)
  data_test["ModifiedDate"] = result
  display(data_test)
else:
  print(f"Error: {response.text}")
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[19], line 4
#       1 headers = {"Content-Type": "application/json"}
#       2 import requests
# ----> 4 response = requests.post(scoring_uri, data=data_json, headers=headers)
#       6 if response.status_code == 200:
#       7   result = json.loads(response.json())
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:697, in Session.send(self, request, **kwargs)
#     694 hooks = request.hooks
#     696 # Get the appropriate adapter to use
# --> 697 adapter = self.get_adapter(url=request.url)
#     699 # Start time (approximately) of the request
#     700 start = preferred_clock()
#
# File c:\Users\Hp ProBook 640 G4\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:794, in Session.get_adapter(self, url)
#     791         return adapter
#     793 # Nothing matches :-/
# --> 794 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for "['http://12c7573b-6592-4f10-8112-25a182703aff.centralindia.azurecontainer.io/score']"
