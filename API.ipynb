# %% [markdown]
# # Implementacion de API

# %%
import pandas as pd

# Datos prueba
data_test =  pd.read_csv("iar_Reservaciones.csv")
# Out:
# C:\Users\Karla Palma\AppData\Local\Temp\ipykernel_32636\1950885766.py:6: DtypeWarning: Columns (22,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_test =  pd.read_csv("iar_Reservaciones.csv")

# %%
data_dict = data_test.to_dict(orient='list')

data_test
# Out:
#         ID_Reserva   Fecha_hoy  h_res_fec h_res_fec_ok h_res_fec_okt  \
# 0                0  2019-08-16   20190816  2019-08-16     2019-08-16
# 1                1  2019-10-22   20191022  2019-10-22     2019-10-22
# 2                2  2019-10-28   20191028  2019-10-28     2019-10-28
# 3                3  2019-10-28   20191028  2019-10-28     2019-10-28
# 4                4  2019-10-28   20191028  2019-10-28     2019-10-28
# ...            ...         ...        ...          ...           ...
# 202997      202997  2020-04-10   20190410  2019-04-10     2019-04-10
# 202998      202998  2020-06-17   20190617  2019-06-17     2019-06-17
# 202999      202999  2020-05-30   20190530  2019-05-30     2019-05-30
# 203000      203000  2020-08-10   20190810  2019-08-10     2019-08-10
# 203001      203001  2020-02-24   20190224  2019-02-24     2019-02-24
#
#         h_num_per  aa_h_num_per  h_num_adu  aa_h_num_adu  h_num_men  ...  \
# 0               2             0          2             0          0  ...
# 1               4             0          4             0          0  ...
# 2               2             0          2             0          0  ...
# 3               4             0          3             0          0  ...
# 4               2             0          2             0          0  ...
# ...           ...           ...        ...           ...        ...  ...
# 202997          0             2          0             2          0  ...
# 202998          0             2          0             2          0  ...
# 202999          0             3          0             2          0  ...
# 203000          0             2          0             2          0  ...
# 203001          0             2          0             2          0  ...
#
#          h_edo             h_codigop  h_correo_e  h_nom  h_tfa_total  \
# 0       EMX     01500                        NaN    NaN      2659.98
# 1       EGT     023541                       NaN    NaN      1764.00
# 2       EMC     59800                        NaN    NaN      2660.04
# 3       EGT     37219                        NaN    NaN      1995.03
# 4       EMX     15300                        NaN    NaN     13369.92
# ...        ...                   ...         ...    ...          ...
# 202997  EMC     58197                        NaN    NaN         0.00
# 202998  EGR     5165165                      NaN    NaN         0.00
# 202999  EMC     60110                        NaN    NaN         0.00
# 203000  EMC     60432                        NaN    NaN         0.00
# 203001  EMC     61606                        NaN    NaN         0.00
#
#         aa_h_tfa_total  moneda_cve  h_ult_cam_fec  h_ult_cam_fec_ok  \
# 0                 0.00           1       20191110       2019-11-10
# 1                 0.00           1       20191205       2019-12-05
# 2                 0.00           1       20191205       2019-12-05
# 3                 0.00           1       20191211       2019-12-11
# 4                 0.00           1       20191212       2019-12-12
# ...                ...         ...            ...               ...
# 202997         2659.95           1       20190410       2019-04-10
# 202998          171.00           1       20190617       2019-06-17
# 202999         2659.98           1       20190602       2019-06-02
# 203000         7900.96           1       20190812       2019-08-12
# 203001         2212.00           1       20190228       2019-02-28
#
#         h_ult_cam_fec_okt
# 0              2019-11-10
# 1              2019-12-05
# 2              2019-12-05
# 3              2019-12-11
# 4              2019-12-12
# ...                   ...
# 202997         2019-04-10
# 202998         2019-06-17
# 202999         2019-06-02
# 203000         2019-08-12
# 203001         2019-02-28
#
# [203002 rows x 49 columns]

# %%
import json

# Formateado para la API:
data_json = json.dumps({"data": [data_dict]})

suri = open("uri.json", "r")
scoring_uri = json.load(suri)["URI"][0]
suri.close()

# %%
import requests
headers = {"Content-Type": "application/json"}
response = requests.post(scoring_uri, data=data_json, headers=headers)

# %%
headers = {"Content-Type": "application/json"}
import requests

response = requests.post(scoring_uri, data=data_json, headers=headers)

if response.status_code == 200:
  result = json.loads(response.json())
  print(result)
  data_test["ModifiedDate"] = result
  display(data_test)
else:
  print(f"Error: {response.text}")
# Out:
# "['NameStyle', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'CompanyName', 'SalesPerson', 'EmailAdress', 'PasswordHash', 'rowguid', 'PasswordSalt'] not found in axis"
#         ID_Reserva   Fecha_hoy  h_res_fec h_res_fec_ok h_res_fec_okt  \
# 0                0  2019-08-16   20190816  2019-08-16     2019-08-16
# 1                1  2019-10-22   20191022  2019-10-22     2019-10-22
# 2                2  2019-10-28   20191028  2019-10-28     2019-10-28
# 3                3  2019-10-28   20191028  2019-10-28     2019-10-28
# 4                4  2019-10-28   20191028  2019-10-28     2019-10-28
# ...            ...         ...        ...          ...           ...
# 202997      202997  2020-04-10   20190410  2019-04-10     2019-04-10
# 202998      202998  2020-06-17   20190617  2019-06-17     2019-06-17
# 202999      202999  2020-05-30   20190530  2019-05-30     2019-05-30
# 203000      203000  2020-08-10   20190810  2019-08-10     2019-08-10
# 203001      203001  2020-02-24   20190224  2019-02-24     2019-02-24
#
#         h_num_per  aa_h_num_per  h_num_adu  aa_h_num_adu  h_num_men  ...  \
# 0               2             0          2             0          0  ...
# 1               4             0          4             0          0  ...
# 2               2             0          2             0          0  ...
# 3               4             0          3             0          0  ...
# 4               2             0          2             0          0  ...
# ...           ...           ...        ...           ...        ...  ...
# 202997          0             2          0             2          0  ...
# 202998          0             2          0             2          0  ...
# 202999          0             3          0             2          0  ...
# 203000          0             2          0             2          0  ...
# 203001          0             2          0             2          0  ...
#
#                    h_codigop  h_correo_e  h_nom  h_tfa_total  aa_h_tfa_total  \
# 0       01500                        NaN    NaN      2659.98            0.00
# 1       023541                       NaN    NaN      1764.00            0.00
# 2       59800                        NaN    NaN      2660.04            0.00
# 3       37219                        NaN    NaN      1995.03            0.00
# 4       15300                        NaN    NaN     13369.92            0.00
# ...                      ...         ...    ...          ...             ...
# 202997  58197                        NaN    NaN         0.00         2659.95
# 202998  5165165                      NaN    NaN         0.00          171.00
# 202999  60110                        NaN    NaN         0.00         2659.98
# 203000  60432                        NaN    NaN         0.00         7900.96
# 203001  61606                        NaN    NaN         0.00         2212.00
#
#         moneda_cve  h_ult_cam_fec  h_ult_cam_fec_ok  h_ult_cam_fec_okt  \
# 0                1       20191110       2019-11-10          2019-11-10
# 1                1       20191205       2019-12-05          2019-12-05
# 2                1       20191205       2019-12-05          2019-12-05
# 3                1       20191211       2019-12-11          2019-12-11
# 4                1       20191212       2019-12-12          2019-12-12
# ...            ...            ...               ...                ...
# 202997           1       20190410       2019-04-10          2019-04-10
# 202998           1       20190617       2019-06-17          2019-06-17
# 202999           1       20190602       2019-06-02          2019-06-02
# 203000           1       20190812       2019-08-12          2019-08-12
# 203001           1       20190228       2019-02-28          2019-02-28
#
#                                              ModifiedDate
# 0       "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 1       "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 2       "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 3       "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 4       "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# ...                                                   ...
# 202997  "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 202998  "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 202999  "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 203000  "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
# 203001  "['NameStyle', 'Title', 'FirstName', 'MiddleNa...
#
# [203002 rows x 50 columns]
